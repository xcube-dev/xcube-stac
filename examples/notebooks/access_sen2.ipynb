# %%
from dask.distributed import Client
from xcube.core.store import new_data_store

# %%
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:36673' processes=4 threads=16, memory=30.15 GiB>

# %%
credentials = {
    "key": "O0M0CUQIDQO9TDZ4D8NR",
    "secret": "qPUyXs9G6j8on6MY5KPhQNHuA5uZTqxEscrbBCGx",
}
store = new_data_store("stac-cdse", stack_mode=True, **credentials)
bbox = [
    29.386939788333212,
    53.16233384987463,
    29.38925624089212,
    53.163636088441415,
]
bbox_utm = [659574, 5892990, 659724, 5893140]
ds = store.open_data(
    data_id="SENTINEL-2",
    bbox=bbox_utm,
    time_range=["2023-11-01", "2023-11-06"],
    processing_level="L2A",
    spatial_res=10,
    tile_size=(16, 16),
    crs="EPSG:32635",
    bands=[
        "B01",
        "B02",
        "B03",
        "B04",
        "B05",
        "B06",
        "B07",
        "B08",
        "B8A",
        "B09",
        "B11",
        "B12",
        "SCL",
    ],
)
print(ds)
store_file = new_data_store("file")
store_file.write_data(ds, "minicube_test2.zarr", replace=True)
# Out:
# /home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/pystac_client/item_search.py:447: DoesNotConformTo: Server does not conform to SORT
#   warnings.warn(DoesNotConformTo("SORT"))
# 2023-11-01
# 2023-11-04
# 2023-11-06
# <xarray.Dataset> Size: 40kB
# Dimensions:  (time: 3, y: 16, x: 16)
# Coordinates:
#   * y        (y) float64 128B 5.893e+06 5.893e+06 ... 5.893e+06 5.893e+06
#   * x        (x) float64 128B 6.596e+05 6.596e+05 ... 6.597e+05 6.597e+05
#   * time     (time) datetime64[ns] 24B 2023-11-01 2023-11-04 2023-11-06
# Data variables: (12/14)
#     B01      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B02      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B03      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B04      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B05      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B06      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     ...       ...
#     B8A      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B09      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B11      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     B12      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     SCL      (time, y, x) float32 3kB dask.array<chunksize=(1, 16, 16), meta=np.ndarray>
#     crs      int64 8B 0
# 2024-11-20 15:23:59,599 - distributed.worker - ERROR - Compute Failed
# Key:       ('open_rasterio-getitem-getitem-ad51d4c7e31dd6885a9fc316331b348a', 5, 2)
# State:     executing
# Task:  <Task ('open_rasterio-getitem-getitem-ad51d4c7e31dd6885a9fc316331b348a', 5, 2) getter(...)>
# Exception: "RasterioIOError('Access Denied')"
# Traceback: '  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/dask/array/core.py", line 122, in getter\n    c = np.asarray(c)\n        ^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 578, in __array__\n    return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)\n                      ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 583, in get_duck_array\n    return self.array.get_duck_array()\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 794, in get_duck_array\n    return self.array.get_duck_array()\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 657, in get_duck_array\n    array = self.array[self.key]\n            ~~~~~~~~~~^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 455, in __getitem__\n    return indexing.explicit_indexing_adapter(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 1018, in explicit_indexing_adapter\n    result = raw_indexing_method(raw_key.tuple)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 430, in _getitem\n    self.manager.acquire(needs_lock=False), self.vrt_params\n    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 193, in acquire\n    file, _ = self._acquire_with_cache_info(needs_lock)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 981, in _single_band_open\n    riods=rasterio.open(*args, **kwargs),\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper\n    return f(*args, **kwds)\n           ^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/__init__.py", line 355, in open\n    dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__\n'
#
# 2024-11-20 15:23:59,599 - distributed.worker - ERROR - Compute Failed
# Key:       ('open_rasterio-getitem-getitem-17912c0d2c39c1673f3e9cfe8b4ce287', 0, 2)
# State:     executing
# Task:  <Task ('open_rasterio-getitem-getitem-17912c0d2c39c1673f3e9cfe8b4ce287', 0, 2) getter(...)>
# Exception: "RasterioIOError('Access Denied')"
# Traceback: '  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/dask/array/core.py", line 122, in getter\n    c = np.asarray(c)\n        ^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 578, in __array__\n    return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)\n                      ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 583, in get_duck_array\n    return self.array.get_duck_array()\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 794, in get_duck_array\n    return self.array.get_duck_array()\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 657, in get_duck_array\n    array = self.array[self.key]\n            ~~~~~~~~~~^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 455, in __getitem__\n    return indexing.explicit_indexing_adapter(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 1018, in explicit_indexing_adapter\n    result = raw_indexing_method(raw_key.tuple)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 430, in _getitem\n    self.manager.acquire(needs_lock=False), self.vrt_params\n    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 193, in acquire\n    file, _ = self._acquire_with_cache_info(needs_lock)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 981, in _single_band_open\n    riods=rasterio.open(*args, **kwargs),\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper\n    return f(*args, **kwds)\n           ^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/__init__.py", line 355, in open\n    dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__\n'
#
# 2024-11-20 15:23:59,599 - distributed.worker - ERROR - Compute Failed
# Key:       ('open_rasterio-getitem-getitem-0db8df8f1e6ca87957d8c756fddeecbc', 0, 2)
# State:     executing
# Task:  <Task ('open_rasterio-getitem-getitem-0db8df8f1e6ca87957d8c756fddeecbc', 0, 2) getter(...)>
# Exception: "RasterioIOError('Access Denied')"
# Traceback: '  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/dask/array/core.py", line 122, in getter\n    c = np.asarray(c)\n        ^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 578, in __array__\n    return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)\n                      ^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 583, in get_duck_array\n    return self.array.get_duck_array()\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 794, in get_duck_array\n    return self.array.get_duck_array()\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 657, in get_duck_array\n    array = self.array[self.key]\n            ~~~~~~~~~~^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 455, in __getitem__\n    return indexing.explicit_indexing_adapter(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py", line 1018, in explicit_indexing_adapter\n    result = raw_indexing_method(raw_key.tuple)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 430, in _getitem\n    self.manager.acquire(needs_lock=False), self.vrt_params\n    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 193, in acquire\n    file, _ = self._acquire_with_cache_info(needs_lock)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py", line 217, in _acquire_with_cache_info\n    file = self._opener(*self._args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py", line 981, in _single_band_open\n    riods=rasterio.open(*args, **kwargs),\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/env.py", line 463, in wrapper\n    return f(*args, **kwds)\n           ^^^^^^^^^^^^^^^^\n  File "/home/konstantin/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/__init__.py", line 355, in open\n    dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "rasterio/_base.pyx", line 312, in rasterio._base.DatasetBase.__init__\n'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py:211, in _acquire_with_cache_info()
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/lru_cache.py:56, in __getitem__()
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function _single_band_open at 0x770a7e1a2ac0>, ('s3://eodata/Sentinel-2/MSI/L2A/2023/11/04/S2A_MSIL2A_20231104T092141_N0509_R093_T35UPV_20231104T134703.SAFE/GRANULE/L2A_T35UPV_A043705_20231104T092333/IMG_DATA/R20m/T35UPV_20231104T092141_B06_20m.jp2',), 'r', (('bidx', 0), ('sharing', False)), '87a2e1bd-d036-4327-8a12-33a9cf35b7af']
#
# During handling of the above exception, another exception occurred:
#
# CPLE_AWSAccessDeniedError                 Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_AWSAccessDeniedError: Access Denied
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[3], line 39
#      37 print(ds)
#      38 store_file = new_data_store("file")
# ---> 39 store_file.write_data(ds, "minicube_test2.zarr", replace=True)
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xcube/core/store/fs/store.py:380, in BaseFsDataStore.write_data(self, data, data_id, writer_id, replace, **write_params)
#     378 fs_path = self._convert_data_id_into_fs_path(data_id)
#     379 self.fs.makedirs(self.root, exist_ok=True)
# --> 380 written_fs_path = writer.write_data(
#     381     data, fs_path, replace=replace, fs=self.fs, root=self.root, **write_params
#     382 )
#     383 # Verify, accessors fulfill their write_data() contract
#     384 assert_true(
#     385     fs_path == written_fs_path,
#     386     message="FsDataAccessor implementations must "
#     387     "return the data_id passed in.",
#     388 )
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xcube/core/store/fs/impl/dataset.py:184, in DatasetZarrFsDataAccessor.write_data(self, data, data_id, replace, **write_params)
#     182 consolidated = write_params.pop("consolidated", True)
#     183 try:
# --> 184     data.to_zarr(
#     185         zarr_store,
#     186         mode="w" if replace else None,
#     187         consolidated=consolidated,
#     188         **write_params,
#     189     )
#     190 except ValueError as e:
#     191     raise DataStoreError(f"Failed to write" f" dataset {data_id!r}: {e}") from e
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/dataset.py:2595, in Dataset.to_zarr(self, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options, zarr_version, zarr_format, write_empty_chunks, chunkmanager_store_kwargs)
#    2427 """Write dataset contents to a zarr group.
#    2428
#    2429 Zarr chunks are determined in the following way:
#    (...)
#    2591     The I/O user guide, with more details and examples.
#    2592 """
#    2593 from xarray.backends.api import to_zarr
# -> 2595 return to_zarr(  # type: ignore[call-overload,misc]
#    2596     self,
#    2597     store=store,
#    2598     chunk_store=chunk_store,
#    2599     storage_options=storage_options,
#    2600     mode=mode,
#    2601     synchronizer=synchronizer,
#    2602     group=group,
#    2603     encoding=encoding,
#    2604     compute=compute,
#    2605     consolidated=consolidated,
#    2606     append_dim=append_dim,
#    2607     region=region,
#    2608     safe_chunks=safe_chunks,
#    2609     zarr_version=zarr_version,
#    2610     zarr_format=zarr_format,
#    2611     write_empty_chunks=write_empty_chunks,
#    2612     chunkmanager_store_kwargs=chunkmanager_store_kwargs,
#    2613 )
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/api.py:2240, in to_zarr(dataset, store, chunk_store, mode, synchronizer, group, encoding, compute, consolidated, append_dim, region, safe_chunks, storage_options, zarr_version, zarr_format, write_empty_chunks, chunkmanager_store_kwargs)
#    2238 # TODO: figure out how to properly handle unlimited_dims
#    2239 dump_to_store(dataset, zstore, writer, encoding=encoding)
# -> 2240 writes = writer.sync(
#    2241     compute=compute, chunkmanager_store_kwargs=chunkmanager_store_kwargs
#    2242 )
#    2244 if compute:
#    2245     _finalize_store(writes, zstore)
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/common.py:277, in ArrayWriter.sync(self, compute, chunkmanager_store_kwargs)
#     274 if chunkmanager_store_kwargs is None:
#     275     chunkmanager_store_kwargs = {}
# --> 277 delayed_store = chunkmanager.store(
#     278     self.sources,
#     279     self.targets,
#     280     lock=self.lock,
#     281     compute=compute,
#     282     flush=True,
#     283     regions=self.regions,
#     284     **chunkmanager_store_kwargs,
#     285 )
#     286 self.sources = []
#     287 self.targets = []
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/namedarray/daskmanager.py:249, in DaskManager.store(self, sources, targets, **kwargs)
#     241 def store(
#     242     self,
#     243     sources: Any | Sequence[Any],
#     244     targets: Any,
#     245     **kwargs: Any,
#     246 ) -> Any:
#     247     from dask.array import store
# --> 249     return store(
#     250         sources=sources,
#     251         targets=targets,
#     252         **kwargs,
#     253     )
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/dask/array/core.py:1282, in store(***failed resolving arguments***)
#    1280 elif compute:
#    1281     store_dsk = HighLevelGraph(layers, dependencies)
# -> 1282     compute_as_if_collection(Array, store_dsk, map_keys, **kwargs)
#    1283     return None
#    1285 else:
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/dask/base.py:397, in compute_as_if_collection(cls, dsk, keys, scheduler, get, **kwargs)
#     395 schedule = get_scheduler(scheduler=scheduler, cls=cls, get=get)
#     396 dsk2 = optimization_function(cls)(dsk, keys, **kwargs)
# --> 397 return schedule(dsk2, keys, **kwargs)
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/distributed/client.py:3493, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3491         should_rejoin = False
#    3492 try:
# -> 3493     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3494 finally:
#    3495     for f in futures.values():
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/distributed/client.py:2566, in Client.gather(self, futures, errors, direct, asynchronous)
#    2563     local_worker = None
#    2565 with shorten_traceback():
# -> 2566     return self.sync(
#    2567         self._gather,
#    2568         futures,
#    2569         errors=errors,
#    2570         direct=direct,
#    2571         local_worker=local_worker,
#    2572         asynchronous=asynchronous,
#    2573     )
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py:578, in __array__()
#     574 def __array__(
#     575     self, dtype: np.typing.DTypeLike = None, /, *, copy: bool | None = None
#     576 ) -> np.ndarray:
#     577     if Version(np.__version__) >= Version("2.0.0"):
# --> 578         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     579     else:
#     580         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py:583, in get_duck_array()
#     582 def get_duck_array(self):
# --> 583     return self.array.get_duck_array()
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py:794, in get_duck_array()
#     793 def get_duck_array(self):
# --> 794     return self.array.get_duck_array()
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py:657, in get_duck_array()
#     653     array = apply_indexer(self.array, self.key)
#     654 else:
#     655     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     656     # it may wrap a BackendArray so use its __getitem__
# --> 657     array = self.array[self.key]
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py:455, in __getitem__()
#     454 def __getitem__(self, key):
# --> 455     return indexing.explicit_indexing_adapter(
#     456         key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#     457     )
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/core/indexing.py:1018, in explicit_indexing_adapter()
#     996 """Support explicit indexing by delegating to a raw indexing method.
#     997
#     998 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1015 Indexing result, in the form of a duck numpy-array.
#    1016 """
#    1017 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1018 result = raw_indexing_method(raw_key.tuple)
#    1019 if numpy_indices.tuple:
#    1020     # index the loaded np.ndarray
#    1021     indexable = NumpyIndexingAdapter(result)
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py:430, in _getitem()
#     427 else:
#     428     with self.lock:
#     429         riods = _ensure_warped_vrt(
# --> 430             self.manager.acquire(needs_lock=False), self.vrt_params
#     431         )
#     432         out = riods.read(band_key, window=window, masked=self.masked)
#     433         if self._unsigned_dtype is not None:
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py:193, in acquire()
#     178 def acquire(self, needs_lock=True):
#     179     """Acquire a file object from the manager.
#     180
#     181     A new file is only opened if it has expired from the
#    (...)
#     191         An open file object, as returned by ``opener(*args, **kwargs)``.
#     192     """
# --> 193     file, _ = self._acquire_with_cache_info(needs_lock)
#     194     return file
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/xarray/backends/file_manager.py:217, in _acquire_with_cache_info()
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rioxarray/_io.py:981, in _single_band_open()
#     976 def _single_band_open(*args, bidx=0, **kwargs):
#     977     """
#     978     Open file as if it only has a single band
#     979     """
#     980     return SingleBandDatasetReader(
# --> 981         riods=rasterio.open(*args, **kwargs),
#     982         bidx=bidx,
#     983     )
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/env.py:463, in wrapper()
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File ~/micromamba/envs/xcube-stac/lib/python3.12/site-packages/rasterio/__init__.py:355, in open()
#     352     path = _parse_path(raw_dataset_path)
#     354 if mode == "r":
# --> 355     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     356 elif mode == "r+":
#     357     dataset = get_writer_for_path(path, driver=driver)(
#     358         path, mode, driver=driver, sharing=sharing, **kwargs
#     359     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: Access Denied
