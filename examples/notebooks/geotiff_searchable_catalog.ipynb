# %% [markdown]
# # Load GeoTiff file from a seachable STAC catalog
#
# This notebook shows an example how to load a GeoTIFF file from a searchable STAC catalog.
#
# A searchable catalog implements the [STAC API - Item Search](https://github.com/radiantearth/stac-api-spec/tree/release/v1.0.0/item-search) conformance class, which provides the ability to search for STAC Item objects across collections.
#
# ### Setup
# In order to run this notebook you may install [`xcube_stac`](https://github.com/xcube-dev/xcube-stac), following the [README](../README.md).
#
# Now, we first import everything we need:

# %%
# %%time
from xcube.core.store import new_data_store, get_data_store_params_schema
import itertools
# Out:
# CPU times: user 3.76 s, sys: 277 ms, total: 4.04 s
# Wall time: 2.31 s

# %% [markdown]
# First, we get the store parameters needed to initialize a STAC [data store](https://xcube.readthedocs.io/en/latest/dataaccess.html#data-store-framework).

# %%
# %%time
store_params = get_data_store_params_schema("stac")
store_params
# Out:
# CPU times: user 222 ms, sys: 58 ms, total: 280 ms
# Wall time: 279 ms

# %% [markdown]
# We determine the url of the [Earth Search](https://element84.com/earth-search/) STAC catalog and initiate a STAC [data store](https://xcube.readthedocs.io/en/latest/dataaccess.html#data-store-framework), where the `xcube-stac` plugin is recognized by setting the first argument to `"stac"` in the `new_data_store` function.

# %%
# %%time
store = new_data_store("stac", url="https://earth-search.aws.element84.com/v1")
# Out:
# CPU times: user 12.9 ms, sys: 2.09 ms, total: 15 ms
# Wall time: 2.71 s

# %% [markdown]
# The data IDs point to a [STAC item's JSON](https://github.com/radiantearth/stac-spec/blob/master/item-spec/item-spec.md) and are specified by the segment of the URL that follows the catalog's URL. The data IDs can be streamed using the following code where we show the first 10 data IDs as an example.

# %%
# %%time
data_ids = store.get_data_ids()
list(itertools.islice(data_ids, 10))
# Out:
# CPU times: user 5.5 ms, sys: 1.01 ms, total: 6.51 ms
# Wall time: 1.05 s
# ['collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20260218T110052_20260218T110109_063272_07F1E2',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20260218T110027_20260218T110052_063272_07F1E2',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20260218T110002_20260218T110027_063272_07F1E2',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20260218T105937_20260218T110002_063272_07F1E2',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20260218T105912_20260218T105937_063272_07F1E2',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20260218T105843_20260218T105912_063272_07F1E2',
#  'collections/sentinel-1-grd/items/S1C_EW_GRDM_1SDH_20260218T104209_20260218T104242_006409_00CE69',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDH_20260218T100725_20260218T100738_063272_07F1DC',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDH_20260218T100700_20260218T100725_063272_07F1DC',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDH_20260218T100635_20260218T100700_063272_07F1DC']

# %% [markdown]
# In the next step, we can search for items using search parameters. The following code shows which search parameters are available.

# %%
# %%time
search_params = store.get_search_params_schema()
search_params
# Out:
# CPU times: user 27 μs, sys: 0 ns, total: 27 μs
# Wall time: 30.3 μs

# %% [markdown]
# Now, let's search for Sentinel-2 L2a data in the region of Lake Constance for the period from June 1st to June 5th, 2020.

# %%
# %%time
descriptors = list(
    store.search_data(
        collections=["sentinel-2-l2a"],
        bbox=[9, 47, 10, 48],
        time_range=["2020-07-01", "2020-07-05"],
    )
)
[d.to_dict() for d in descriptors]
# Out:
# CPU times: user 414 ms, sys: 13.1 ms, total: 427 ms
# Wall time: 9.63 s
# [{'data_id': 'collections/sentinel-2-l2a/items/S2B_32TMT_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.769228745834018,
#    46.85909198885185,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-05T10:27:51.180000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32TMT_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.762146064135137,
#    46.85901560719437,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-05T10:27:51.177000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32TNT_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.85664904260366,
#    10.467263761969436,
#    47.85369284462768],
#   'time_range': ('2020-07-05T10:27:47.411000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32TNT_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.85664904260366,
#    10.467263761969436,
#    47.85369284462768],
#   'time_range': ('2020-07-05T10:27:47.409000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UMU_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.097183381629907,
#    47.76162472180052,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-05T10:27:36.382000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UMU_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.089444803260868,
#    47.76156358517808,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-05T10:27:36.380000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UNU_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.755827810229526,
#    10.493255611539013,
#    48.75300400802843],
#   'time_range': ('2020-07-05T10:27:33.029000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UNU_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.755827810229526,
#    10.493255611539013,
#    48.75300400802843],
#   'time_range': ('2020-07-05T10:27:33.027000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TMT_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.662878883910047,
#    46.85818510451771,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-03T10:37:50.578000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TMT_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.662878883910047,
#    46.85818510451771,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-03T10:37:50.577000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TNT_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.86545413497558,
#    9.683667661181989,
#    47.85369284462768],
#   'time_range': ('2020-07-03T10:37:45.862000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TNT_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.86660884670375,
#    9.683264107355098,
#    47.85369284462768],
#   'time_range': ('2020-07-03T10:37:45.861000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UMU_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.639190643894996,
#    47.75741268155721,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-03T10:37:36.335000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UMU_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.639190643894996,
#    47.75741268155721,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-03T10:37:36.334000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UNU_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.764447765603194,
#    10.093645911255322,
#    48.75300400802843],
#   'time_range': ('2020-07-03T10:37:31.959000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UNU_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.76336985243686,
#    10.094053887015043,
#    48.75300400802843],
#   'time_range': ('2020-07-03T10:37:31.959000Z', None)}]

# %% [markdown]
# In the next step, we can open the data for each data ID. The following code shows which parameters are available for opening the data.

# %%
# %%time
open_params = store.get_open_data_params_schema()
open_params
# Out:
# CPU times: user 28 μs, sys: 2 μs, total: 30 μs
# Wall time: 31.9 μs

# %% [markdown]
# We select the band red (B04), green (B03), and blue (B02) and lazily load the corresponding data.

# %%
# %%time
ds = store.open_data(
    descriptors[3].data_id, 
    asset_names=["blue", "green", "nir"], 
    apply_scaling=True,
    data_type="dataset",
)
ds
# Out:
# CPU times: user 177 ms, sys: 51.7 ms, total: 229 ms
# Wall time: 27 s
# <xarray.Dataset> Size: 1GB
# Dimensions:      (x: 10980, y: 10980)
# Coordinates:
#   * x            (x) float64 88kB 5e+05 5e+05 5e+05 ... 6.098e+05 6.098e+05
#   * y            (y) float64 88kB 5.3e+06 5.3e+06 5.3e+06 ... 5.19e+06 5.19e+06
#     spatial_ref  int64 8B 0
# Data variables:
#     blue         (y, x) float32 482MB dask.array<chunksize=(8192, 8192), meta=np.ndarray>
#     green        (y, x) float32 482MB dask.array<chunksize=(8192, 8192), meta=np.ndarray>
#     nir          (y, x) float32 482MB dask.array<chunksize=(8192, 8192), meta=np.ndarray>
# Attributes:
#     stac_catalog_url:    https://earth-search.aws.element84.com/v1
#     stac_item_id:        S2B_32TNT_20200705_0_L2A
#     xcube_stac_version:  1.2.0.dev0

# %% [markdown]
# We plot the loaded data as an example below.

# %%
# %%time
ds.green[:5000:10, :5000:10].plot(vmin=0.0, vmax=0.2)
# Out:
# CPU times: user 935 ms, sys: 625 ms, total: 1.56 s
# Wall time: 20.4 s

# %% [markdown]
# We can also open a GeoTIFF as a [xcube's multi-resolution  dataset](https://xcube.readthedocs.io/en/latest/mldatasets.html#xcube-multi-resolution-datasets), where we can select the level of resolution, shown below.

# %%
# %%time
mlds = store.open_data(
    descriptors[3].data_id,
    asset_names=["blue", "green", "nir"],
    apply_scaling=True,
    data_type="mldataset",
)
mlds.num_levels
# Out:
# CPU times: user 36.1 ms, sys: 3.81 ms, total: 39.9 ms
# Wall time: 2.59 s
# 5

# %%
ds = mlds.get_dataset(4)
ds
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:      (x: 687, y: 687)
# Coordinates:
#   * x            (x) float64 5kB 5.001e+05 5.002e+05 ... 6.095e+05 6.097e+05
#   * y            (y) float64 5kB 5.3e+06 5.3e+06 5.3e+06 ... 5.19e+06 5.19e+06
#     spatial_ref  int64 8B 0
# Data variables:
#     blue         (y, x) float32 2MB dask.array<chunksize=(687, 687), meta=np.ndarray>
#     green        (y, x) float32 2MB dask.array<chunksize=(687, 687), meta=np.ndarray>
#     nir          (y, x) float32 2MB dask.array<chunksize=(687, 687), meta=np.ndarray>
# Attributes:
#     stac_catalog_url:    https://earth-search.aws.element84.com/v1
#     stac_item_id:        S2B_32TNT_20200705_0_L2A
#     xcube_stac_version:  1.2.0.dev0

# %%
# %%time
ds.green[:312, :312].plot(vmin=0.0, vmax=0.2)
# Out:
# CPU times: user 32.8 ms, sys: 2.92 ms, total: 35.7 ms
# Wall time: 343 ms
