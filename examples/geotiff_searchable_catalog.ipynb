# %% [markdown]
# # Load GeoTiff file from a seachable STAC catalog
#
# This notebook shows an example how to load a GeoTIFF file from a searchable STAC catalog.
#
# A searchable catalog implements the [STAC API - Item Search](https://github.com/radiantearth/stac-api-spec/tree/release/v1.0.0/item-search) conformance class, which provides the ability to search for STAC Item objects across collections.
#
# ### Setup
# In order to run this notebook you need to install [`xcube_stac`](https://github.com/xcube-dev/xcube-stac). You may install [`xcube_stac`](https://github.com/xcube-dev/xcube-stac) directly from the git repository by cloning the repository, directing into `xcube-stac`, and following the steps below:
#
# ```bash
# conda env create -f environment.yml
# conda activate xcube-stac
# pip install .
# ```
#
# Note that [`xcube_stac`](https://github.com/xcube-dev/xcube-stac) is a plugin of [`xcube`](https://xcube.readthedocs.io/en/latest/), where `xcube` is included in the `environment.yml`.
#
# Now, we first import everything we need:

# %%
# %%time
from xcube.core.store import new_data_store, get_data_store_params_schema
import itertools
# Out:
# CPU times: user 2.76 s, sys: 169 ms, total: 2.93 s
# Wall time: 976 ms

# %% [markdown]
# First, we get the store parameters needed to initialize a STAC [data store](https://xcube.readthedocs.io/en/latest/dataaccess.html#data-store-framework).

# %%
# %%time
store_params = get_data_store_params_schema("stac")
store_params
# Out:
# CPU times: user 145 ms, sys: 27.9 ms, total: 172 ms
# Wall time: 172 ms

# %% [markdown]
# We determine the url of the [Earth Search](https://element84.com/earth-search/) STAC catalog and initiate a STAC [data store](https://xcube.readthedocs.io/en/latest/dataaccess.html#data-store-framework), where the `xcube-stac` plugin is recognized by setting the first argument to `"stac"` in the `new_data_store` function.

# %%
# %%time
url = "https://earth-search.aws.element84.com/v1"
store = new_data_store("stac", url=url)
# Out:
# CPU times: user 8.87 ms, sys: 77 µs, total: 8.95 ms
# Wall time: 595 ms

# %% [markdown]
# The data IDs point to a [STAC item's JSON](https://github.com/radiantearth/stac-spec/blob/master/item-spec/item-spec.md) and are specified by the segment of the URL that follows the catalog's URL. The data IDs can be streamed using the following code where we show the first 10 data IDs as an example.

# %%
# %%time
data_ids = store.get_data_ids()
list(itertools.islice(data_ids, 10))
# Out:
# CPU times: user 5.62 ms, sys: 0 ns, total: 5.62 ms
# Wall time: 936 ms
# ['collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDV_20240710T083016_20240710T083116_054696_06A8B8',
#  'collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDV_20240710T082911_20240710T083016_054696_06A8B8',
#  'collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDH_20240710T082322_20240710T082346_054696_06A8B6',
#  'collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDH_20240710T082222_20240710T082322_054696_06A8B6',
#  'collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDH_20240710T082122_20240710T082222_054696_06A8B6',
#  'collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDH_20240710T082022_20240710T082122_054696_06A8B6',
#  'collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDH_20240710T081922_20240710T082022_054696_06A8B6',
#  'collections/sentinel-1-grd/items/S1A_EW_GRDM_1SDH_20240710T081818_20240710T081922_054696_06A8B6',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20240710T073909_20240710T073938_054695_06A8B2',
#  'collections/sentinel-1-grd/items/S1A_IW_GRDH_1SDV_20240710T073840_20240710T073909_054695_06A8B2']

# %% [markdown]
# In the next step, we can search for items using search parameters. The following code shows which search parameters are available.

# %%
# %%time
search_params = store.get_search_params_schema()
search_params
# Out:
# CPU times: user 19 µs, sys: 0 ns, total: 19 µs
# Wall time: 20.7 µs

# %% [markdown]
# Now, let's search for Sentinel-2 L2a data in the region of Lake Constance for the period from June 1st to June 5th, 2020.

# %%
# %%time
descriptors = list(
    store.search_data(
        collections=["sentinel-2-l2a"],
        bbox=[9, 47, 10, 48],
        time_range=["2020-07-01", "2020-07-05"],
    )
)
[d.to_dict() for d in descriptors]
# Out:
# CPU times: user 181 ms, sys: 21.8 ms, total: 203 ms
# Wall time: 23.5 s
# [{'data_id': 'collections/sentinel-2-l2a/items/S2B_32TMT_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.769228745834018,
#    46.85909198885185,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-05T10:27:51.180000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32TMT_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.762146064135137,
#    46.85901560719437,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-05T10:27:51.177000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32TNT_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.85664904260366,
#    10.467263761969436,
#    47.85369284462768],
#   'time_range': ('2020-07-05T10:27:47.411000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32TNT_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.85664904260366,
#    10.467263761969436,
#    47.85369284462768],
#   'time_range': ('2020-07-05T10:27:47.409000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UMU_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.097183381629907,
#    47.76162472180052,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-05T10:27:36.382000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UMU_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.089444803260868,
#    47.76156358517808,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-05T10:27:36.380000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UNU_20200705_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.755827810229526,
#    10.493255611539013,
#    48.75300400802843],
#   'time_range': ('2020-07-05T10:27:33.029000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2B_32UNU_20200705_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.755827810229526,
#    10.493255611539013,
#    48.75300400802843],
#   'time_range': ('2020-07-05T10:27:33.027000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TMT_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.662878883910047,
#    46.85818510451771,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-03T10:37:50.578000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TMT_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.662878883910047,
#    46.85818510451771,
#    9.130456971519783,
#    47.85361872923358],
#   'time_range': ('2020-07-03T10:37:50.577000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TNT_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.86545413497558,
#    9.683667661181989,
#    47.85369284462768],
#   'time_range': ('2020-07-03T10:37:45.862000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32TNT_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999746010269408,
#    46.86660884670375,
#    9.683264107355098,
#    47.85369284462768],
#   'time_range': ('2020-07-03T10:37:45.861000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UMU_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.639190643894996,
#    47.75741268155721,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-03T10:37:36.335000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UMU_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [7.639190643894996,
#    47.75741268155721,
#    9.132768981529203,
#    48.752927528985374],
#   'time_range': ('2020-07-03T10:37:36.334000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UNU_20200703_1_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.764447765603194,
#    10.093645911255322,
#    48.75300400802843],
#   'time_range': ('2020-07-03T10:37:31.959000Z', None)},
#  {'data_id': 'collections/sentinel-2-l2a/items/S2A_32UNU_20200703_0_L2A',
#   'data_type': 'dataset',
#   'bbox': [8.999741508947045,
#    47.76336985243686,
#    10.094053887015043,
#    48.75300400802843],
#   'time_range': ('2020-07-03T10:37:31.959000Z', None)}]

# %% [markdown]
# In the next step, we can open the data for each data ID. The following code shows which parameters are available for opening the data.

# %%
# %%time
open_params = store.get_open_data_params_schema()
open_params
# Out:
# CPU times: user 2.68 ms, sys: 0 ns, total: 2.68 ms
# Wall time: 2.68 ms

# %% [markdown]
# We select the band red (B04), green (B03), and blue (B02) and lazily load the corresponding data. Note that we assign the `data_type` to get dataset.

# %%
# %%time
ds = store.open_data(descriptors[2].data_id, asset_names=["blue", "green", "nir"], data_type="dataset")
ds
# Out:
# CPU times: user 64 ms, sys: 7.93 ms, total: 72 ms
# Wall time: 3.55 s
# <xarray.Dataset> Size: 724MB
# Dimensions:      (x: 10980, y: 10980)
# Coordinates:
#   * x            (x) float64 88kB 5e+05 5e+05 5e+05 ... 6.098e+05 6.098e+05
#   * y            (y) float64 88kB 5.3e+06 5.3e+06 5.3e+06 ... 5.19e+06 5.19e+06
#     spatial_ref  int64 8B 0
# Data variables:
#     blue         (y, x) uint16 241MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     green        (y, x) uint16 241MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     nir          (y, x) uint16 241MB dask.array<chunksize=(512, 512), meta=np.ndarray>
# Attributes:
#     source:   s3://sentinel-cogs/sentinel-s2-l2a-cogs/32/T/NT/2020/7/S2B_32TN...

# %% [markdown]
# We plot the loaded data as an example below.

# %%
# %%time
ds.green[:5000:10, :5000:10].plot(vmax=2000)
# Out:
# CPU times: user 637 ms, sys: 281 ms, total: 918 ms
# Wall time: 2min 6s

# %% [markdown]
# Since we open a GeoTIFF, the default opener represents the data in the [xcube's multi-resolution  dataset](https://xcube.readthedocs.io/en/latest/mldatasets.html#xcube-multi-resolution-datasets), where we can select the level of resolution, shown below.

# %%
# %%time
mlds = store.open_data(descriptors[2].data_id, asset_names=["blue", "green", "nir"])
mlds.num_levels
# Out:
# CPU times: user 37.1 ms, sys: 8.67 ms, total: 45.8 ms
# Wall time: 3.4 s
# 5

# %%
ds = mlds.get_dataset(4)
ds
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:      (x: 687, y: 687)
# Coordinates:
#   * x            (x) float64 5kB 5.001e+05 5.002e+05 ... 6.095e+05 6.097e+05
#   * y            (y) float64 5kB 5.3e+06 5.3e+06 5.3e+06 ... 5.19e+06 5.19e+06
#     spatial_ref  int64 8B 0
# Data variables:
#     blue         (y, x) uint16 944kB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     green        (y, x) uint16 944kB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     nir          (y, x) uint16 944kB dask.array<chunksize=(512, 512), meta=np.ndarray>
# Attributes:
#     source:   s3://sentinel-cogs/sentinel-s2-l2a-cogs/32/T/NT/2020/7/S2B_32TN...

# %%
# %%time
ds.green[:312, :312].plot(vmax=2000)
# Out:
# CPU times: user 35.9 ms, sys: 510 µs, total: 36.4 ms
# Wall time: 1.83 s
